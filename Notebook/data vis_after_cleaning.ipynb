# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('final_dataset.csv')
df
# Out:
#         Unnamed: 0  Rating                                             Review
# 0                0       1  way way way overpriced amazon sell subscribe s...
# 1                1       5  well hot ice cold decade family enjoy brand te...
# 2                2       5  sparkling review write simple carbonate water ...
# 3                3       4  coffee hound like coffee hit coffee drinker ho...
# 4                4       1  weak flavor drink numi gunpowder green 4 year ...
# ...            ...     ...                                                ...
# 149530      149531       2  soso apricot syrup expect intense apricot flav...
# 149531      149532       3  amazon review scramble m rate neutral star war...
# 149532      149533       2  pumpkin flavor excited order receive coffee di...
# 149533      149534       1           organic bar raw bar taste good buy taste
# 149534      149535       2  fine loose tea disappointed tea arrive fine us...
#
# [149535 rows x 3 columns]

# %%
df['word_count'] = df['Review'].astype(str).apply(lambda x: len(x.split()))

# %% [markdown]
# ## Data visualization after cleaning

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Rating', y='word_count', data=df, palette='Set2')
plt.title(" Box Plot: Word Count Distribution by Rating")
plt.xlabel("Rating")
plt.ylabel("Word Count")
plt.show()

# STEP 3: Histogram — Word Count by Rating
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='word_count', hue='Rating', multiple='stack', palette='Set2', bins=30)
plt.title(" Histogram: Word Count Distribution by Rating")
plt.xlabel("Word Count")
plt.ylabel("Number of Reviews")
plt.legend(title='Rating')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10732\1315757586.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Rating', y='word_count', data=df, palette='Set2')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10732\1315757586.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Rating')

# %%
min_word_count_per_rating = df.groupby('Rating')['word_count'].min()

# Display the result
print(" Min word count per Rating:")
print(min_word_count_per_rating)
# Out:
#  Min word count per Rating:
# Rating
# 1    4
# 2    5
# 3    4
# 4    4
# 5    4
# Name: word_count, dtype: int64

# %%
max_word_count_per_rating = df.groupby('Rating')['word_count'].max()

# Display the result
print(" Max word count per Rating:")
print(max_word_count_per_rating)
# Out:
#  Max word count per Rating:
# Rating
# 1    142
# 2    130
# 3    142
# 4    164
# 5    131
# Name: word_count, dtype: int64
